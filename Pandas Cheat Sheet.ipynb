# %%
import pandas as pd

# %%
df = pd.read_csv('Fraud.csv')

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00    False
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6362620, step=1)

# %% [markdown]
# ## DataFrame and Series Basics - Selecting Rows and Columns

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df.iloc[1,2] #index: row,column
# Out:
# 'Fully remote'

# %%
df.loc[[1,2]]#selecting rows
# Out:
#                                 MainBranch           Employment    RemoteWork  \
# ResponseId
# 1                            None of these                  NaN           NaN
# 2           I am a developer by profession  Employed, full-time  Fully remote
#
#                                     CodingActivities EdLevel LearnCode  \
# ResponseId
# 1                                                NaN     NaN       NaN
# 2           Hobby;Contribute to open-source projects     NaN       NaN
#
#            LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro  \
# ResponseId
# 1                      NaN                  NaN       NaN          NaN
# 2                      NaN                  NaN       NaN          NaN
#
#            DevType OrgSize PurchaseInfluence BuyNewTool Country  \
# ResponseId
# 1              NaN     NaN               NaN        NaN     NaN
# 2              NaN     NaN               NaN        NaN  Canada
#
# ...

# %%
df.loc[2,'MainBranch']
# Out:
# 'I am a developer by profession'

# %%
df.loc[[1,2,3,4,5],['MainBranch','Employment','LanguageHaveWorkedWith']]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                       LanguageHaveWorkedWith
# ResponseId
# 1                           NaN                                          NaN
# 2           Employed, full-time                        JavaScript;TypeScript
# 3           Employed, full-time            C#;C++;HTML/CSS;JavaScript;Python
# 4           Employed, full-time                 C#;JavaScript;SQL;TypeScript
# 5           Employed, full-time  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %% [markdown]
# ## Indexes - How to Set, Reset, and Use Indexes

# %%
df = pd.read_csv('survey_results_schema.csv')
pd.set_option("display.max_columns", 20)
pd.set_option("display.max_rows", 20)
df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
df.set_index('type',inplace=True)

# %%
df.loc['MC']
# Out:
#          qid             qname  \
# type
# MC      QID2        MainBranch
# MC    QID296        Employment
# MC    QID308        RemoteWork
# MC    QID297  CodingActivities
# MC     QID25           EdLevel
# ...      ...               ...
# MC    QID290       Frequency_2
# MC    QID290       Frequency_3
# MC    QID294       TrueFalse_1
# MC    QID294       TrueFalse_2
# MC    QID294       TrueFalse_3
#
#                                                question force_resp selector
# type
# MC    Which of the following options best describes ...       True     SAVR
# MC    Which of the following best describes your cur...      False     MAVR
# MC    Which best describes your current work situation?      False     SAVR
# MC    Which of the following best describes the code...      False     MAVR
# MC    Which of the following best describes the high...      False     SAVR
# ...                                                 ...        ...      ...
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#     type     qid        qname  \
# 0     DB   QID16           S0
# 1   Meta   QID12     MetaInfo
# 2     DB    QID1           S1
# 3     MC    QID2   MainBranch
# 4     MC  QID296   Employment
# ..   ...     ...          ...
# 74    MC  QID290  Frequency_2
# 75    MC  QID290  Frequency_3
# 76    MC  QID294  TrueFalse_1
# 77    MC  QID294  TrueFalse_2
# 78    MC  QID294  TrueFalse_3
#
#                                              question force_resp selector
# 0   <div><span style="font-size:19px;"><strong>Hel...      False       TB
# 1                                   Browser Meta Info      False  Browser
# 2   <span style="font-size:22px; font-family: aria...      False       TB
# 3   Which of the following options best describes ...       True     SAVR
# 4   Which of the following best describes your cur...      False     MAVR
# ..                                                ...        ...      ...
# 74  Interacting with people outside of your immedi...        NaN     MAVR
# ...

# %%
# Out:
# 0              S0
# 1        MetaInfo
# 2              S1
# 3      MainBranch
# 4      Employment
#          ...
# 74    Frequency_2
# 75    Frequency_3
# 76    TrueFalse_1
# 77    TrueFalse_2
# 78    TrueFalse_3
# Name: qname, Length: 79, dtype: object

# %% [markdown]
# ## Filtering - Using Conditionals to Filter Rows and Columns

# %%
filt = df['nameDest'].str.contains('M',na=False)

# %%
df.loc[filt,'nameDest']
# Out:
# 0          M1979787155
# 1          M2044282225
# 4          M1230701703
# 5           M573487274
# 6           M408069119
#               ...
# 6362312    M1112540487
# 6362314    M1878955882
# 6362316     M675916850
# 6362318    M1126011651
# 6362319     M747723689
# Name: nameDest, Length: 2151495, dtype: object

# %%
type_is= ['PAYMENT','TRANSFER']
filt_type = df['type'].isin(type_is)

# %%
df.loc[filt_type,'type']
# Out:
# 0           PAYMENT
# 1           PAYMENT
# 2          TRANSFER
# 4           PAYMENT
# 5           PAYMENT
#              ...
# 6362610    TRANSFER
# 6362612    TRANSFER
# 6362614    TRANSFER
# 6362616    TRANSFER
# 6362618    TRANSFER
# Name: type, Length: 2684404, dtype: object

# %%
filt
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 6362615    False
# 6362616    False
# 6362617    False
# 6362618    False
# 6362619    False
# Name: nameDest, Length: 6362620, dtype: bool

# %%
df.loc[filt & filt_type]
# Out:
#          step     type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1  PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1           1  PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 4           1  PAYMENT  11668.14  C2048537720        41554.0        29885.86
# 5           1  PAYMENT   7817.71    C90045638        53860.0        46042.29
# 6           1  PAYMENT   7107.77   C154988899       183195.0       176087.23
# ...       ...      ...       ...          ...            ...             ...
# 6362312   718  PAYMENT   8178.01  C1213413071        11742.0         3563.99
# 6362314   718  PAYMENT  17841.23  C1045048098        10182.0            0.00
# 6362316   718  PAYMENT   1022.91  C1203084509           12.0            0.00
# 6362318   718  PAYMENT   4109.57   C673558958         5521.0         1411.43
# 6362319   718  PAYMENT   8634.29   C642813806       518802.0       510167.71
#
# ...

# %% [markdown]
# ## Updating rows and columns

# %%
a = (df['amount'] > 200000)
df[a]
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 15          1  CASH_OUT   229133.94   C905080434       15325.00
# 19          1  TRANSFER   215310.30  C1670993182         705.00
# 24          1  TRANSFER   311685.89  C1984094095       10835.00
# 82          1  TRANSFER   224606.64   C873175411           0.00
# 84          1  TRANSFER   379856.23  C1449772539           0.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 15                  0.0   C476402209         5083.00        51513.44        0
# ...

# %%
data = df.loc[filt & filt_type & a]
data
# Out:
#          step     type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 5990632   419  PAYMENT  230549.18  C1010785271          653.0             0.0
# 6078483   518  PAYMENT  203795.61  C1019618849            0.0             0.0
# 6082891   522  PAYMENT  207417.70  C1591112582            0.0             0.0
# 6102910   524  PAYMENT  219732.65   C590102634            0.0             0.0
# 6142147   545  PAYMENT  238637.98  C1557311221            0.0             0.0
# 6163788   550  PAYMENT  225974.21  C1970882834            0.0             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 5990632   M928086060             0.0             0.0        1               1
# 6078483   M942583605             0.0             0.0        1               1
# 6082891  M2089516721             0.0             0.0        1               1
# 6102910  M1157448222             0.0             0.0        1               1
# ...

# %%
l = [data.index]
l
idmax
# Out:
# [Int64Index([5990632, 6078483, 6082891, 6102910, 6142147, 6163788], dtype='int64')]

# %%
for i in l:
    df.loc[i,['isFlaggedFraud','isFraud']] = 1

# %%
ratio = (df.amount/df.step).idxmax()
df.loc[ratio,'nameOrig']
# Out:
# 'C197491520'

# %%
df['isFraud'].map({0:'NO',1:'YES'})
# Out:
# 0           NO
# 1           NO
# 2          YES
# 3          YES
# 4           NO
#           ...
# 6362615    YES
# 6362616    YES
# 6362617    YES
# 6362618    YES
# 6362619    YES
# Name: isFraud, Length: 6362620, dtype: object

# %% [markdown]
# ## Add/Remove rows and columns

# %%
items = {'first' : ['John','Joe','Corey'],
      'last' : ['Doe', 'Doe', 'Schafer'],
      'email' : ['johndoe@gmail.com', 'joes22@gmail.com', 'coryschafer@gmail.com']}

# %%
df = pd.DataFrame(items)
df
# Out:
#    first     last                  email
# 0   John      Doe      johndoe@gmail.com
# 1    Joe      Doe       joes22@gmail.com
# 2  Corey  Schafer  coryschafer@gmail.com

# %%
df['full-name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                  email      full-name
# 0   John      Doe      johndoe@gmail.com       John Doe
# 1    Joe      Doe       joes22@gmail.com        Joe Doe
# 2  Corey  Schafer  coryschafer@gmail.com  Corey Schafer

# %%
df.drop(columns = ['first','last'],inplace=True)
df
# Out:
#                    email      full-name
# 0      johndoe@gmail.com       John Doe
# 1       joes22@gmail.com        Joe Doe
# 2  coryschafer@gmail.com  Corey Schafer

# %%
df['full-name'].str.split(' ',expand=True)
# Out:
#        0        1
# 0   John      Doe
# 1    Joe      Doe
# 2  Corey  Schafer

# %%
df[['first','last']] = df['full-name'].str.split(' ',expand=True)

# %%
df
# Out:
#                    email      full-name  first     last
# 0      johndoe@gmail.com       John Doe   John      Doe
# 1       joes22@gmail.com        Joe Doe    Joe      Doe
# 2  coryschafer@gmail.com  Corey Schafer  Corey  Schafer

# %%
df.append({'first' : 'Tony','last' : 'Stark'},ignore_index=True)
# Out:
#                    email      full-name  first     last
# 0      johndoe@gmail.com       John Doe   John      Doe
# 1       joes22@gmail.com        Joe Doe    Joe      Doe
# 2  coryschafer@gmail.com  Corey Schafer  Corey  Schafer
# 3                    NaN            NaN   Tony    Stark

# %%
df.drop([1],axis=0)
# Out:
#                    email      full-name  first     last
# 0      johndoe@gmail.com       John Doe   John      Doe
# 2  coryschafer@gmail.com  Corey Schafer  Corey  Schafer

# %%
df.drop(['full-name'],axis=1)
# Out:
#                    email  first     last
# 0      johndoe@gmail.com   John      Doe
# 1       joes22@gmail.com    Joe      Doe
# 2  coryschafer@gmail.com  Corey  Schafer

# %% [markdown]
# ## Sorting Data

# %%
df.sort_values(by=['last','first','email'],ascending=[False,True,False])
# Out:
#                    email      full-name  first     last
# 2  coryschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       joes22@gmail.com        Joe Doe    Joe      Doe
# 0      johndoe@gmail.com       John Doe   John      Doe

# %%
df.sort_index()
# Out:
#                    email      full-name  first     last
# 0      johndoe@gmail.com       John Doe   John      Doe
# 1       joes22@gmail.com        Joe Doe    Joe      Doe
# 2  coryschafer@gmail.com  Corey Schafer  Corey  Schafer

# %%
df.sort_values(by='amount')
df
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 3686583   276  TRANSFER  92445516.64  C1715283297            0.0
# 4060598   300  TRANSFER  73823490.36  C2127282686            0.0
# 4146397   303  TRANSFER  71172480.42  C2044643633            0.0
# 3946920   286  TRANSFER  69886731.30  C1425667947            0.0
# 3911956   284  TRANSFER  69337316.27  C1584456031            0.0
# ...       ...       ...          ...          ...            ...
# 2736447   212  CASH_OUT         0.00  C1510987794            0.0
# 6362461   730  CASH_OUT         0.00   C729003789            0.0
# 6168500   554  CASH_OUT         0.00    C10965156            0.0
# 6296015   671  CASH_OUT         0.00  C1960007029            0.0
# 3760289   279  CASH_OUT         0.00   C539112012            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 3686583             0.0   C439737079    9.595980e+03    9.245511e+07        0
# ...

# %%
df[['amount','nameOrig']].head(10)
# Out:
#               amount     nameOrig
# 3686583  92445516.64  C1715283297
# 4060598  73823490.36  C2127282686
# 4146397  71172480.42  C2044643633
# 3946920  69886731.30  C1425667947
# 3911956  69337316.27  C1584456031
# 3937152  67500761.29   C811810230
# 4105338  66761272.21   C420748282
# 3892529  64234448.19  C1139847449
# 3991638  63847992.58   C300140823
# 4143801  63294839.63   C372535854

# %%
df['amount'].nlargest(10)
# Out:
# 3686583    92445516.64
# 4060598    73823490.36
# 4146397    71172480.42
# 3946920    69886731.30
# 3911956    69337316.27
# 3937152    67500761.29
# 4105338    66761272.21
# 3892529    64234448.19
# 3991638    63847992.58
# 4143801    63294839.63
# Name: amount, dtype: float64

# %%
df.nsmallest(10,'amount')
# Out:
#          step      type  amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 5563714   387  CASH_OUT     0.0  C1294472700            0.0             0.0
# 6266414   617  CASH_OUT     0.0  C1971175979            0.0             0.0
# 6205440   586  CASH_OUT     0.0  C1303719003            0.0             0.0
# 6351226   702  CASH_OUT     0.0  C1461113533            0.0             0.0
# 6281483   646  CASH_OUT     0.0  C2060908932            0.0             0.0
# 6362585   741  CASH_OUT     0.0   C312737633            0.0             0.0
# 5996410   425  CASH_OUT     0.0    C69493310            0.0             0.0
# 3247298   250  CASH_OUT     0.0   C521393327            0.0             0.0
# 5996408   425  CASH_OUT     0.0   C832555372            0.0             0.0
# 6281485   646  CASH_OUT     0.0  C1997645312            0.0             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
df.amount.median()
# Out:
# 74871.94

# %% [markdown]
# ## Grouping and Aggregating

# %%
df['isFraud'].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# 0    6362604
# 1         16
# Name: isFlaggedFraud, dtype: int64

# %%
df['type'].value_counts(normalize=True)
# Out:
# CASH_OUT    0.351663
# PAYMENT     0.338146
# CASH_IN     0.219923
# TRANSFER    0.083756
# DEBIT       0.006512
# Name: type, dtype: float64

# %%
grp = df.groupby('type')
grp.get_group('CASH_OUT')
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2361318   190  CASH_OUT  10000000.0   C950353738     10000000.0
# 6344707   692  CASH_OUT  10000000.0   C819618584     10000000.0
# 6073255   514  CASH_OUT  10000000.0  C1274141620     10000000.0
# 3214345   249  CASH_OUT  10000000.0  C1919400809     10000000.0
# 5563506   386  CASH_OUT  10000000.0   C634268681     10000000.0
# ...       ...       ...         ...          ...            ...
# 2736447   212  CASH_OUT         0.0  C1510987794            0.0
# 6362461   730  CASH_OUT         0.0   C729003789            0.0
# 6168500   554  CASH_OUT         0.0    C10965156            0.0
# 6296015   671  CASH_OUT         0.0  C1960007029            0.0
# 3760289   279  CASH_OUT         0.0   C539112012            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2361318             0.0  C1401949177         2876.18     10002876.18        1
# ...

# %%
filt = df['type'] == 'CASH_OUT'
df.loc[filt]['isFraud'].value_counts()
# Out:
# 0    2233384
# 1       4116
# Name: isFraud, dtype: int64

# %%
df['nameDest'].value_counts()
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# M1728844180      1
# M302843979       1
# M1938977592      1
# M469964425       1
# C1156763710      1
# Name: nameDest, Length: 2722362, dtype: int64

# %%
grp['amount'].value_counts(normalize=True).loc['TRANSFER']
# Out:
# amount
# 10000000.00    0.005751
# 198408.20      0.000006
# 443116.03      0.000006
# 196.43         0.000004
# 731.36         0.000004
#                  ...
# 69337316.27    0.000002
# 69886731.30    0.000002
# 71172480.42    0.000002
# 73823490.36    0.000002
# 92445516.64    0.000002
# Name: amount, Length: 528820, dtype: float64

# %%
grp['amount'].median()
# Out:
# type
# CASH_IN     143427.710
# CASH_OUT    147072.185
# DEBIT         3048.990
# PAYMENT       9482.190
# TRANSFER    486308.390
# Name: amount, dtype: float64

# %%
grp['amount'].median().loc['TRANSFER']
# Out:
# 486308.39

# %%
s = pd.DataFrame(grp['amount'].agg(['median','mean','min']))
s
# Out:
#               median           mean   min
# type
# CASH_IN   143427.710  168920.242004  0.04
# CASH_OUT  147072.185  176273.964346  0.00
# DEBIT       3048.990    5483.665314  0.55
# PAYMENT     9482.190   13057.604660  0.02
# TRANSFER  486308.390  910647.009645  2.60

# %%
filt = df['type'] == 'PAYMENT'
df.loc[filt]['nameDest'].str.contains('M').sum()
# Out:
# 2151495

# %%
type_respondants = df['type'].value_counts()

# %%
type_is_payment = grp['isFraud'].apply(lambda x : x.sum())

# %%
payment_df = pd.concat([type_respondants,type_is_payment],axis='columns')
payment_df
# Out:
#              type  isFraud
# CASH_OUT  2237500     4116
# PAYMENT   2151495        0
# CASH_IN   1399284        0
# TRANSFER   532909     4097
# DEBIT       41432        0

# %%
payment_df.rename(columns={'type':'Transaction Type', 'isFraud' : 'Fraud transactions'},inplace=True)

# %%
payment_df
# Out:
#           Transaction Type  Fraud transactions
# CASH_OUT           2237500                4116
# PAYMENT            2151495                   0
# CASH_IN            1399284                   0
# TRANSFER            532909                4097
# DEBIT                41432                   0

# %%
payment_df['percentage%'] = (payment_df['Fraud transactions']/payment_df['Transaction Type'])*100
payment_df
# Out:
#           Transaction Type  Fraud transactions  percentage%
# CASH_OUT           2237500                4116     0.183955
# PAYMENT            2151495                   0     0.000000
# CASH_IN            1399284                   0     0.000000
# TRANSFER            532909                4097     0.768799
# DEBIT                41432                   0     0.000000

# %%
na_vals = ['NA','Missing',np.nan]
df = pd.read_csv('survey_results_public.csv',index_col=0,na_values=na_vals)
pd.set_option("display.max_rows", 25)
pd.set_option("display.max_columns", 78)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df['ConvertedCompYearly'].head(10)
# Out:
# ResponseId
# 1          NaN
# 2          NaN
# 3      40205.0
# 4     215232.0
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9      49056.0
# 10         NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 67845.0

# %%
df.median()
# Out:
# C:\Users\GARIMA~1\AppData\Local\Temp/ipykernel_10044/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  VCHostingPersonal use  VCHostingProfessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             WorkExp  ConvertedCompYearly
# count  36769.000000         3.807100e+04
# mean      10.242378         1.707613e+05
# std        8.706850         7.814132e+05
# min        0.000000         1.000000e+00
# 25%        4.000000         3.583200e+04
# 50%        8.000000         6.784500e+04
# 75%       15.000000         1.200000e+05
# ...

# %%
df['ConvertedCompYearly'].count()
# Out:
# 38071

# %%
df['CodingActivities'].value_counts()
# Out:
# Hobby                                                                                                                                  18118
# I don’t code outside of work                                                                                                            7311
#                                                                                                                                        ...
# Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;Other (please specify):;School or academic work        1
# Bootstrapping a business;Other (please specify):;School or academic work                                                                   1
# Name: CodingActivities, Length: 63, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
country_grp = df.groupby('Country')

# %%
country_grp.get_group('India')
# Out:
#                                 MainBranch  \
# ResponseId
# 7              I code primarily as a hobby
# 8           I am a developer by profession
# ...                                    ...
# 73258                I am learning to code
# 73259       I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# ...                                        ...
# 73258                       Student, full-time
# 73259                      Employed, full-time
#
#                                       RemoteWork CodingActivities  \
# ResponseId
# 7                                            NaN              NaN
# 8                                            NaN              NaN
# ...                                          ...              ...
# 73258                                        NaN              NaN
# ...

# %%
filt = df['Country'] == 'China'
df.loc[filt]
# Out:
#                                 MainBranch  \
# ResponseId
# 361         I am a developer by profession
# 443         I am a developer by profession
# ...                                    ...
# 72813       I am a developer by profession
# 73000          I code primarily as a hobby
#
#                                                    Employment  \
# ResponseId
# 361                                       Employed, full-time
# 443         Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 72813                                     Employed, full-time
# 73000                                      Student, full-time
#
#                                       RemoteWork  \
# ResponseId
# 361         Hybrid (some remote, some in-person)
# 443         Hybrid (some remote, some in-person)
# ...                                          ...
# 72813       Hybrid (some remote, some in-person)
# ...

# %%
df.loc[filt]['NEWCollabToolsWantToWorkWith'].value_counts()
# Out:
# Visual Studio Code                                                                 53
# Vim;Visual Studio Code                                                             25
#                                                                                    ..
# CLion;IntelliJ;Rider;Visual Studio Code;Xcode                                       1
# Emacs;GoLand;IPython/Jupyter;Neovim;PyCharm;Sublime Text;Vim;Visual Studio Code     1
# Name: NEWCollabToolsWantToWorkWith, Length: 312, dtype: int64

# %%
country_grp['NEWCollabToolsWantToWorkWith'].value_counts()
# Out:
# Country      NEWCollabToolsWantToWorkWith
# Afghanistan  Visual Studio Code                                                                     9
#              Android Studio                                                                         3
#              Notepad++                                                                              2
#              Visual Studio;Visual Studio Code                                                       2
#              Android Studio;Atom;CLion;Emacs;GoLand;IntelliJ;IPython/Jupyter;Notepad++;Vim;Xcode    1
#                                                                                                    ..
# Zimbabwe     PyCharm                                                                                1
#              PyCharm;Visual Studio;Visual Studio Code;Webstorm                                      1
#              RStudio                                                                                1
# ...

# %%
country_grp['NEWCollabToolsWantToWorkWith'].value_counts(normalize=True).loc['India']
# Out:
# NEWCollabToolsWantToWorkWith
# Visual Studio Code                            0.149298
# Visual Studio;Visual Studio Code              0.041053
# Android Studio;Visual Studio Code             0.021053
# Notepad++;Visual Studio;Visual Studio Code    0.018596
# Vim;Visual Studio Code                        0.017368
#                                                 ...
# Vim;Visual Studio;Visual Studio Code;Xcode    0.000175
# Vim;Visual Studio;Webstorm                    0.000175
# Vim;Visual Studio;Xcode                       0.000175
# Visual Studio;Visual Studio Code;Webstorm     0.000175
# Visual Studio;Webstorm                        0.000175
# Name: NEWCollabToolsWantToWorkWith, Length: 1708, dtype: float64

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 69318.0

# %%
df[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 332

# %%
country_grp['ConvertedCompYearly'].agg(['mean','median','min','max']) #salary
# Out:
#                                               mean   median     min       max
# Country
# Afghanistan                           33914.666667  10894.0  1634.0  158484.0
# Albania                               24895.148148  15360.0    36.0  106780.0
# Algeria                               12732.888889   7440.0  3504.0   31992.0
# Andorra                               98003.125000  76784.0   192.0  213287.0
# Angola                                 6222.750000   3073.5  1440.0   17304.0
# ...                                            ...      ...     ...       ...
# Venezuela, Bolivarian Republic of...  17079.400000  12000.0   240.0   74400.0
# Viet Nam                              37707.563830  11388.0     1.0  995064.0
# Yemen                                 17464.666667  15000.0  4800.0   40000.0
# Zambia                                 8452.000000   6612.0  4344.0   14400.0
# Zimbabwe                              87596.000000  11400.0  3600.0  568968.0
#
# [180 rows x 4 columns]

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Go').sum())
# Out:
# Country
# Afghanistan                              5
# Albania                                  8
# Algeria                                  2
# Andorra                                  1
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...    11
# Viet Nam                                33
# Yemen                                    0
# Zambia                                   0
# Zimbabwe                                 1
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())

# %%
dataframe = pd.concat([country_respondents,country_uses_python],axis='columns',sort=False)
dataframe
# Out:
#                                                     Country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Monaco                                                    1
# Djibouti                                                  1
# Seychelles                                                1
# Solomon Islands                                           1
# Saint Kitts and Nevis                                     1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
dataframe.rename(columns = {'Country' : 'num_of_respondents', 'LanguageHaveWorkedWith' : 'knows_python'},inplace=True)
dataframe
# Out:
#                                                     num_of_respondents  \
# United States of America                                         13543
# India                                                             6639
# Germany                                                           5395
# United Kingdom of Great Britain and Northern Ir...                4190
# Canada                                                            2490
# ...                                                                ...
# Monaco                                                               1
# Djibouti                                                             1
# Seychelles                                                           1
# Solomon Islands                                                      1
# Saint Kitts and Nevis                                                1
#
#                                                     knows_python
# ...

# %% [markdown]
# ## Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import numpy as np
df = pd.DataFrame({'first':['Joe','NA','John','Joey','Corey',np.nan,'Tia'],
                  'last' : ['Doe',np.nan,'Doe','Schafer','NA',np.nan,'NA'],
                  'email' : ['joe@gmail.com','NA','john@yahoo.com','joey@outlook.com','Missing',np.nan,'missing'],
                  'age':[12,'00',34,None,np.nan,35,36]})
df
# Out:
#    first     last             email   age
# 0    Joe      Doe     joe@gmail.com    12
# 1     NA      NaN                NA    00
# 2   John      Doe    john@yahoo.com    34
# 3   Joey  Schafer  joey@outlook.com  None
# 4  Corey       NA           Missing   NaN
# 5    NaN      NaN               NaN    35
# 6    Tia       NA           missing    36

# %%
df.dropna()
df.dropna(axis='index',how='any')
# Out:
#   first last           email age
# 0   Joe  Doe   joe@gmail.com  12
# 2  John  Doe  john@yahoo.com  34
# 6   Tia   NA         missing  36

# %%
df.dropna(axis='index',how='all',subset=['last','email'])
# Out:
#    first     last             email   age
# 0    Joe      Doe     joe@gmail.com    12
# 1     NA      NaN                NA    00
# 2   John      Doe    john@yahoo.com    34
# 3   Joey  Schafer  joey@outlook.com  None
# 4  Corey       NA           Missing   NaN
# 6    Tia       NA           missing    36

# %%
df.replace(['NA','Missing','missing'],np.nan,inplace=True)

# %%
df
# Out:
#    first     last             email   age
# 0    Joe      Doe     joe@gmail.com    12
# 1    NaN      NaN               NaN    00
# 2   John      Doe    john@yahoo.com    34
# 3   Joey  Schafer  joey@outlook.com  None
# 4  Corey      NaN               NaN   NaN
# 5    NaN      NaN               NaN    35
# 6    Tia      NaN               NaN    36

# %%
df.isna()
df.dropna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1   True   True   True  False
# 2  False  False  False  False
# 3  False  False  False   True
# 4  False   True   True   True
# 5   True   True   True  False
# 6  False   True   True  False

# %%
type('age')#str
type(np.nan)
# Out:
# float

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df.age.mean()
# Out:
# 23.4

# %%
df['age'].unique()
# Out:
# array([12, '00', 34, None, nan, 35, 36], dtype=object)

# %%
na_vals = ['NA','Missing']
df = pd.read_csv('survey_results_public.csv',index_col=0,na_values=na_vals)
pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 20)
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.251307285752338

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# ## Working with Dates and Time Series Data

# %%
df = pd.read_csv('ETH_1H.csv')
df.head()
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M')

# %%
df['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-05-09 17:00:00
# 34493   2016-05-09 16:00:00
# 34494   2016-05-09 15:00:00
# 34495   2016-05-09 14:00:00
# 34496   2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
type('Date')
# Out:
# str

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df['Date'].max()-df['Date'].min()
# Out:
# Timedelta('1437 days 11:00:00')

# %%
filt = ((df['Date'] > '2019') & (df['Date'] <= '2020'))
df.loc[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2544    1577836800000 2020-01-01 00:00:00  ETHUSD  128.84  128.84  128.07
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11296   1546318800000 2019-01-01 05:00:00  ETHUSD  132.09  132.53  132.09
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
#
#         Close       Volume
# 2544   128.11   526.980282
# ...

# %%
df.set_index('Date',inplace=True)
df
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
#                           Volume
# Date
# ...

# %%
df.loc['2019']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2019-12-31 23:00:00   1577833200000  ETHUSD  128.68  128.85  127.82  128.84
# 2019-12-31 22:00:00   1577829600000  ETHUSD  128.40  128.93  127.77  128.68
# 2019-12-31 21:00:00   1577826000000  ETHUSD  127.87  128.41  127.81  128.40
# 2019-12-31 20:00:00   1577822400000  ETHUSD  127.86  128.30  127.86  127.87
# 2019-12-31 19:00:00   1577818800000  ETHUSD  128.78  128.78  127.86  127.86
# ...                             ...     ...     ...     ...     ...     ...
# 2019-01-01 04:00:00   1546315200000  ETHUSD  130.83  133.75  130.83  132.09
# 2019-01-01 03:00:00   1546311600000  ETHUSD  129.79  131.00  129.79  130.83
# 2019-01-01 02:00:00   1546308000000  ETHUSD  130.98  130.98  129.25  129.79
# 2019-01-01 01:00:00   1546304400000  ETHUSD  131.10  131.10  128.72  130.98
# 2019-01-01 00:00:00   1546300800000  ETHUSD  130.80  131.70  130.00  131.10
#
#                           Volume
# Date
# ...

# %%
df.loc['2020-01':'2020-03']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-03-01 00:00:00   1583020800000  ETHUSD  217.35  221.00  216.62  218.09
# 2020-02-29 23:00:00   1583017200000  ETHUSD  222.93  223.96  217.26  217.35
# 2020-02-29 22:00:00   1583013600000  ETHUSD  223.59  223.76  222.32  222.93
# 2020-02-29 21:00:00   1583010000000  ETHUSD  224.81  225.08  223.05  223.59
# 2020-02-29 20:00:00   1583006400000  ETHUSD  225.56  225.56  223.55  224.81
# ...                             ...     ...     ...     ...     ...     ...
# 2020-02-01 04:00:00   1580529600000  ETHUSD  182.65  183.42  181.86  182.03
# 2020-02-01 03:00:00   1580526000000  ETHUSD  183.20  183.51  182.63  182.65
# 2020-02-01 02:00:00   1580522400000  ETHUSD  183.21  184.05  182.98  183.20
# 2020-02-01 01:00:00   1580518800000  ETHUSD  181.20  183.38  181.08  183.21
# 2020-02-01 00:00:00   1580515200000  ETHUSD  179.75  181.20  179.15  181.20
#
#                           Volume
# Date
# ...

# %%
df.loc['2020-01':'2020-03']['Low'].mean()
# Out:
# 236.14248206599697

# %%
df['2020-01':'2020-04']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-01 00:00:00   1585699200000  ETHUSD  133.42  133.57  131.01  132.19
# 2020-03-31 23:00:00   1585695600000  ETHUSD  134.02  134.02  133.15  133.42
# 2020-03-31 22:00:00   1585692000000  ETHUSD  134.58  134.58  133.50  134.02
# 2020-03-31 21:00:00   1585688400000  ETHUSD  134.92  135.40  133.81  134.58
# 2020-03-31 20:00:00   1585684800000  ETHUSD  133.49  135.31  133.49  134.92
# ...                             ...     ...     ...     ...     ...     ...
# 2020-02-01 04:00:00   1580529600000  ETHUSD  182.65  183.42  181.86  182.03
# 2020-02-01 03:00:00   1580526000000  ETHUSD  183.20  183.51  182.63  182.65
# 2020-02-01 02:00:00   1580522400000  ETHUSD  183.21  184.05  182.98  183.20
# 2020-02-01 01:00:00   1580518800000  ETHUSD  181.20  183.38  181.08  183.21
# 2020-02-01 00:00:00   1580515200000  ETHUSD  179.75  181.20  179.15  181.20
#
#                           Volume
# Date
# ...

# %%
df.loc['2020-02-01']['High'].max()
# Out:
# 184.05

# %%
highs = df['High'].resample('D').max() #Daily
highs['2020-02-01']
# Out:
# 184.05

# %%
df.resample('W').agg(['mean','min'])
# Out:
#            Unix Timestamp                       Open                High  \
#                      mean            min        mean     min        mean
# Date
# 2016-05-15   1.463076e+09     1462798800   10.140387    0.00   10.310516
# 2016-05-22   1.463657e+09     1463356800   13.042262   10.06   13.144048
# 2016-05-29   1.464262e+09     1463961600   12.481012   10.41   12.555536
# 2016-06-05   1.464867e+09     1464566400   13.586369   12.41   13.651667
# 2016-06-12   1.465472e+09     1465171200   14.287500   13.83   14.326190
# ...                   ...            ...         ...     ...         ...
# 2020-03-22   1.584617e+12  1584316800000  124.640952  101.06  126.387917
# 2020-03-29   1.585222e+12  1584921600000  133.274762  121.89  134.287857
# 2020-04-05   1.585827e+12  1585526400000  137.517083  124.50  138.314583
# 2020-04-12   1.586432e+12  1586131200000  163.601548  143.04  164.731071
# 2020-04-19   1.586866e+12  1586736000000  156.890137  151.45  157.744384
#
# ...

# %%
df.resample('W').agg({'Close':'mean', 'High':'max','Low':'min','Volume':'sum'}) #weekly
# Out:
#                  Close    High     Low         Volume
# Date
# 2016-05-15   10.205290   12.00    0.00   10988.942273
# 2016-05-22   13.066964   14.77   10.06   40673.495362
# 2016-05-29   12.471012   14.43   10.41   58051.809091
# 2016-06-05   13.594583   16.05   12.41   47351.544496
# 2016-06-12   14.297798   15.75   13.83   52002.171838
# ...                ...     ...     ...            ...
# 2020-03-22  124.636012  153.17  100.70  439980.283707
# 2020-03-29  133.285893  144.14  119.17  230941.584515
# 2020-04-05  137.627440  150.32  124.09  151022.864981
# 2020-04-12  163.693929  176.74  142.87  204715.937994
# 2020-04-19  156.778219  162.15  150.12   50776.889638
#
# [206 rows x 4 columns]

# %% [markdown]
# ##  Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
df = pd.read_csv('survey_results_public.csv',index_col=0)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
filt = df['Country'] == 'India'
india_df = df[filt]
india_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv', sep ='\t')

# %%
india_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx',index_col=0)

# %%
test.head()
# Out:
#                                 MainBranch  \
# ResponseId
# 7              I code primarily as a hobby
# 8           I am a developer by profession
# 66          I am a developer by profession
# 141         I am a developer by profession
# 152         I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# 141                        Employed, full-time
# 152                        Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 7                                            NaN
# 8                                            NaN
# 66          Hybrid (some remote, some in-person)
# 141         Hybrid (some remote, some in-person)
# 152                               Full in-person
#
#                          CodingActivities  \
# ResponseId
# ...

# %%
india_df.to_json('modified.json',orient='records',lines=True)

# %%
test = pd.read_json('modified.json',orient='records',lines=True)
test.head()
# Out:
#                        MainBranch                          Employment  \
# 0     I code primarily as a hobby                  Student, part-time
# 1  I am a developer by profession  Not employed, but looking for work
# 2  I am a developer by profession                 Employed, full-time
# 3  I am a developer by profession                 Employed, full-time
# 4  I am a developer by profession                 Employed, full-time
#
#                              RemoteWork               CodingActivities  \
# 0                                  None                           None
# 1                                  None                           None
# 2  Hybrid (some remote, some in-person)  Hobby;Other (please specify):
# 3  Hybrid (some remote, some in-person)   I don’t code outside of work
# 4                        Full in-person                          Hobby
#
#                                              EdLevel  \
# 0  Secondary school (e.g. American high school, G...
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3.1\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3.1\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3.1\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3.1\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ...
